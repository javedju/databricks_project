-- %% [markdown]
-- ###History and Time Travel
-- 1. Query Delta Lake Table History
-- 2. Query Previous versions of the data
-- 3. Query data from specific time
-- 4. Restore data to aspecific version

-- %% [markdown]
-- **1. Query Delta Lake Table History**

-- %%
DESCRIBE HISTORY demo.delta_lake.companies

-- %% [markdown]
-- **2. Query Data froma Specific Version**

-- %%
SELECT * FROm demo.delta_lake.companies

-- %%
SELECT * FROm demo.delta_lake.companies 
VERSION AS OF 1;

-- %% [markdown]
-- **3. Query data from specific time**

-- %%
SELECT * FROM demo.delta_lake.companies
TIMESTAMP AS OF '2026-05-15T11:27:46.000+00:00'

-- %% [markdown]
-- **4. Restore data to aspecific version**

-- %%
RESTORE TABLE demo.delta_lake.companies VERSION AS OF 1;

-- %%
SELECT * FROM demo.delta_lake.companies

-- %%
DESCRIBE HISTORY demo.delta_lake.companies
