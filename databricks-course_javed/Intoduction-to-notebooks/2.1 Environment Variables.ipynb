# %%
env = 'dev'

# %%
import os
def print_versions():
    import sys
    python_version = sys.version
    db_runtime_version = os.environ.get('DATABRICKS_RUNTIME_VERSION', 'Unknown')
    print(f"Python version: {python_version}")
    print(f"Databricks runtime version: {db_runtime_version}")
