# %% [markdown]
# ### Intoduction to Notebooks

# %%
print("Hello World")
print("Bye")

# %%
print("Hello Again!")

# %% [markdown]
# ### Magic Commands

# %%
# %sql
select "Hello From SQL!" as Greetings
