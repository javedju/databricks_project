# %% [markdown]
# ### Databricks Magic Commands
# - %python, %SQL, %scala, %r : Switch to a different language for a specific cell.
# - %md: Markdown for documenting notebooks
# - %fs: Run file system commands
# - %sh: Install python libraries
# - %run: Include/import another notebook into the current notebook.

# %%
# %fs
ls /databricks-datasets/

# %%
# %sh
ps

# %%
# %pip list

# %%
# %pip install faker

# %%
# %run "/Workspace/Users/javedju2019@gmail.com/databricks-course/2.1 Environment Variables"

# %%
env

# %%
print_versions()

# %%
# %run "./2.1 Environment Variables"
