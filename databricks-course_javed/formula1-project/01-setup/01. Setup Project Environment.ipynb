-- %%
%fs ls 'abfss://formula1@dbextdlake.dfs.core.windows.net/landing'

-- %%
%sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dbc_ext_dl_formula1
    URL 'abfss://formula1@dbextdlake.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL `dbc-sc`)
    COMMENT 'External Location for Formula1 Container'

-- %%
SHOW CATALOGS;

-- %%
CREATE CATALOG IF NOT EXISTS formula1
   MANAGED LOCATION 'abfss://formula1@dbextdlake.dfs.core.windows.net'
   COMMENT 'This is the main catalog for the formula1 project' ;

-- %%
CREATE SCHEMA IF NOT EXISTS formula1.landing;
CREATE SCHEMA IF NOT EXISTS formula1.bronze
    MANAGED LOCATION 'abfss://formula1@dbextdlake.dfs.core.windows.net/bronze';
CREATE SCHEMA IF NOT EXISTS formula1.silver
    MANAGED LOCATION 'abfss://formula1@dbextdlake.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS formula1.gold
    MANAGED LOCATION 'abfss://formula1@dbextdlake.dfs.core.windows.net/gold'

-- %%
SHOW SCHEMAS;

-- %%
SELECT current_catalog();

-- %%
USE CATALOG formula1;
SHOW SCHEMAS;

-- %%
CREATE EXTERNAL VOLUME IF NOT EXISTS  formula1.landing.files
  LOCATION 'abfss://formula1@dbextdlake.dfs.core.windows.net/landing'

-- %%
%fs ls /Volumes/formula1/landing/files
